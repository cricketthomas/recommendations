# %%
import urllib.request
import bs4 as bs
import json 
url = urllib.request.urlopen('https://edraft.com/nfl/stats/leaders/').read() #so this link searches for all content on this url. 
soup = bs.BeautifulSoup(url,'lxml')
stats = [] #storing data here. 

#rows =  soup.find("t", { "class" : "mod-content" }).find('tr'),

for data in soup.select(".Container"):
    a = str(data.text)
    stat = data.find("td", attrs={"class": "TextLeft Name"})
    stat1 = data.find_all("TextLeft Name")
    all_stats ={}
    count = 0
    for link in data.find_all("td", attrs={"class": "TextLeft Name"}):
        player = "player"
        player = '{}{}'.format(player, count)
        count += 1
        playerData = player +":" + link.text +" Count: " + link.next_sibling.get_text()
        #myList.append(playerData)
        all_stats[player] =  link.text +" Count: " + link.next_sibling.get_text()    
    #print(myDict)
    #stats.append(a) 
    record = {
        "title": data.td.get_text(),
        "top_player": stat.get_text() +' ' + stat.next_sibling.get_text(),
        "all_stats": all_stats
    }
    stats.append(record)
#print(*stats, sep='\n')
print(json.dumps({"nfldata": stats}, indent=3))



#making the file so you can read it in your script. 
with open("nflstats.json", "w") as writeJSON:
    json.dump(json.dumps({"nfldata": stats}, indent=3), writeJSON, ensure_ascii=False)
# Out:
# {
#    "nfldata": [
#       {
#          "title": "Passing Yards",
#          "top_player": "Roethlisberger, Ben (PIT) 3945",
#          "all_stats": {
#             "player0": "Roethlisberger, Ben (PIT) Count: 3945",
#             "player1": "Mahomes, Patrick (KC) Count: 3923",
#             "player2": "Ryan, Matt (ATL) Count: 3814",
#             "player3": "Goff, Jared (LAR) Count: 3754",
#             "player4": "Rodgers, Aaron (GB) Count: 3504"
#          }
#       },
#       {
#          "title": "Rushing Yards",
#          "top_player": "Gurley, Todd (LAR) 1175",
#          "all_stats": {
#             "player0": "Gurley, Todd (LAR) Count: 1175",
#             "player1": "Elliott, Ezekiel (DAL) Count: 1149",
#             "player2": "Barkley, Saquon (NYG) Count: 954",
#             "player3": "Lindsay, Phillip (DEN) Count: 937",
#             "player4": "Conner, James (PIT) Count: 909"
#          }
#       },
#       {
#          "title": "Receiving Yards",
#          "top_player": "Jones, Julio (ATL) 1323",
#          "all_stats": {
#             "player0": "Jones, Julio (ATL) Count: 1323",
#             "player1": "Thielen, Adam (MIN) Count: 1166",
#             "player2": "Evans, Mike (TB) Count: 1121",
#             "player3": "Thomas, Michael (NO) Count: 1120",
#             "player4": "Hill, Tyreek (KC) Count: 1119"
#          }
#       },
#       {
#          "title": "Field Goals",
#          "top_player": "Fairbairn, Ka'imi (HOU) 29",
#          "all_stats": {
#             "player0": "Fairbairn, Ka'imi (HOU) Count: 29",
#             "player1": "Myers, Jason (NYJ) Count: 28",
#             "player2": "Rosas, Aldrick (NYG) Count: 26",
#             "player3": "Tucker, Justin (BAL) Count: 25",
#             "player4": "Maher, Brett (DAL) Count: 24"
#          }
#       },
#       {
#          "title": "Tackles",
#          "top_player": "Leonard, Darius (IND) 122",
#          "all_stats": {
#             "player0": "Leonard, Darius (IND) Count: 122",
#             "player1": "Alonso, Kiko (MIA) Count: 106",
#             "player2": "Martinez, Blake (GB) Count: 106",
#             "player3": "Vander Esch, Leighton (DAL) Count: 103",
#             "player4": "Foster, Mason (WAS) Count: 102"
#          }
#       },
#       {
#          "title": "Sacks",
#          "top_player": "Donald, Aaron (LAR) 16.5",
#          "all_stats": {
#             "player0": "Donald, Aaron (LAR) Count: 16.5",
#             "player1": "Miller, Von (DEN) Count: 12.5",
#             "player2": "Jones, Chandler (ARI) Count: 12.0",
#             "player3": "Garrett, Myles (CLE) Count: 11.5",
#             "player4": "Hunter, Danielle (MIN) Count: 11.5"
#          }
#       },
#       {
#          "title": "Interceptions",
#          "top_player": "Howard, Xavien (MIA) 7",
#          "all_stats": {
#             "player0": "Howard, Xavien (MIA) Count: 7",
#             "player1": "Fuller, Kyle (CHI) Count: 6",
#             "player2": "Kazee, Damontae (ATL) Count: 6",
#             "player3": "Jackson, Donte (CAR) Count: 4",
#             "player4": "Jackson, Eddie (CHI) Count: 4"
#          }
#       },
#       {
#          "title": "Punting",
#          "top_player": "Dickson, Michael (SEA) 48.7",
#          "all_stats": {
#             "player0": "Dickson, Michael (SEA) Count: 48.7",
#             "player1": "Johnston, Cameron (PHI) Count: 48.7",
#             "player2": "Lee, Andy (ARI) Count: 48.5",
#             "player3": "Kern, Brett (TEN) Count: 47.4",
#             "player4": "Morstead, Thomas (NO) Count: 47.2"
#          }
#       }
#    ]
# }
