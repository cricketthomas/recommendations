# %%
import urllib.request
import bs4 as bs
import json 
url = urllib.request.urlopen('https://edraft.com/nfl/stats/leaders/').read() #so this link searches for all content on this url. 
soup = bs.BeautifulSoup(url,'lxml')
stats = [] #storing data here. 
#rows =  soup.find("t", { "class" : "mod-content" }).find('tr'),

for data in soup.select(".Container"):
    a = str(data.text)
    stat = data.find("td", attrs={"class": "TextLeft Name"})
    stat1 = data.find_all("TextLeft Name")
    myList = []
    count = 0
    for link in data.find_all("td", attrs={"class": "TextLeft Name"}):
        player = "player"
        player = '{}{}'.format(player, count)
        count += 1
        playerData = player +": " + link.text +" Count: " + link.next_sibling.get_text()
        myList.append(playerData)
    #print(myList)
    #stats.append(a) 
    record = {
        "title": data.td.get_text(),
        "top_player": stat.get_text() +' ' + stat.next_sibling.get_text(),
        "all_stats ": myList
    }
    stats.append(record)
#print(*stats, sep='\n')
print(json.dumps({"nfldata": stats}, indent=3))



#making the file so you can read it in your script. 
with open("nflstats.json", "w") as writeJSON:
    json.dump(json.dumps({"nfldata": stats}, indent=3), writeJSON, ensure_ascii=False)
# Out:
# {
#    "nfldata": [
#       {
#          "title": "Passing Yards",
#          "top_player": "Mahomes, Patrick (KC) 3150",
#          "all_stats ": [
#             "player0: Mahomes, Patrick (KC) Count: 3150",
#             "player1: Goff, Jared (LAR) Count: 3134",
#             "player2: Ryan, Matt (ATL) Count: 3015",
#             "player3: Roethlisberger, Ben (PIT) Count: 2888",
#             "player4: Brady, Tom (NE) Count: 2748"
#          ]
#       },
#       {
#          "title": "Rushing Yards",
#          "top_player": "Gurley, Todd (LAR) 988",
#          "all_stats ": [
#             "player0: Gurley, Todd (LAR) Count: 988",
#             "player1: Elliott, Ezekiel (DAL) Count: 831",
#             "player2: Conner, James (PIT) Count: 771",
#             "player3: Hunt, Kareem (KC) Count: 754",
#             "player4: Gordon III, Melvin (LAC) Count: 672"
#          ]
#       },
#       {
#          "title": "Receiving Yards",
#          "top_player": "Jones, Julio (ATL) 1040",
#          "all_stats ": [
#             "player0: Jones, Julio (ATL) Count: 1040",
#             "player1: Thomas, Michael (NO) Count: 950",
#             "player2: Thielen, Adam (MIN) Count: 947",
#             "player3: Hopkins, DeAndre (HOU) Count: 894",
#             "player4: Hill, Tyreek (KC) Count: 891"
#          ]
#       },
#       {
#          "title": "Field Goals",
#          "top_player": "Gould, Robbie (SF) 21",
#          "all_stats ": [
#             "player0: Gould, Robbie (SF) Count: 21",
#             "player1: Myers, Jason (NYJ) Count: 21",
#             "player2: Crosby, Mason (GB) Count: 19",
#             "player3: Fairbairn, Ka'imi (HOU) Count: 19",
#             "player4: Gostkowski, Stephen (NE) Count: 19"
#          ]
#       },
#       {
#          "title": "Tackles",
#          "top_player": "Leonard, Darius (IND) 96",
#          "all_stats ": [
#             "player0: Leonard, Darius (IND) Count: 96",
#             "player1: Alonso, Kiko (MIA) Count: 89",
#             "player2: Littleton, Cory (LAR) Count: 84",
#             "player3: Hitchens, Anthony (KC) Count: 80",
#             "player4: Foster, Mason (WAS) Count: 79"
#          ]
#       },
#       {
#          "title": "Sacks",
#          "top_player": "Donald, Aaron (LAR) 12.5",
#          "all_stats ": [
#             "player0: Donald, Aaron (LAR) Count: 12.5",
#             "player1: Hunter, Danielle (MIN) Count: 11.5",
#             "player2: Ford, Dee (KC) Count: 9.0",
#             "player3: Garrett, Myles (CLE) Count: 9.0",
#             "player4: Miller, Von (DEN) Count: 9.0"
#          ]
#       },
#       {
#          "title": "Interceptions",
#          "top_player": "Kazee, Damontae (ATL) 5",
#          "all_stats ": [
#             "player0: Kazee, Damontae (ATL) Count: 5",
#             "player1: Fuller, Kyle (CHI) Count: 4",
#             "player2: Jackson, Donte (CAR) Count: 4",
#             "player3: Swearinger Sr., D.J. (WAS) Count: 4",
#             "player4: Adams, Mike (CAR) Count: 3"
#          ]
#       },
#       {
#          "title": "Punting",
#          "top_player": "Martin, Sam (DET) 53.7",
#          "all_stats ": [
#             "player0: Martin, Sam (DET) Count: 53.7",
#             "player1: Johnston, Cameron (PHI) Count: 49.6",
#             "player2: Lee, Andy (ARI) Count: 48.2",
#             "player3: Dickson, Michael (SEA) Count: 48.0",
#             "player4: Koch, Sam (BAL) Count: 47.8"
#          ]
#       }
#    ]
# }
